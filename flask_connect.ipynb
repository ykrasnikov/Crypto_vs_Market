# %%
    # Used to fetch crypto data from the DB
    # this is then used by the Flask app to expose the data as an API

# %%
    # Imports
import pandas as pd
pd.set_option('display.width', 1000)
pd.set_option('display.float_format', lambda x: '%.7f' % x)
import pymongo
import dns.resolver
from secrets import password
from secrets import user

# %%
  # Initialize PyMongo to work with MongoDBs
conn = f'mongodb+srv://{user}:{password}@cluster0.yicgz.mongodb.net/Crypto_vs_Market?retryWrites=true&w=majority'
client = pymongo.MongoClient(conn)

# %%
#Define database and collection
db = client.Crypto_vs_Market
collection= db.crypto_history
collection1= db.VIX
collection2= db.Dollar
collection3= db.Gold
collection4= db.SnP

# %%
# Display crypto history items in MongoDB collection as a pandas dataframe
listings = db.crypto_history.find()

df = pd.DataFrame(list(db.crypto_history.find()))

df
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-5-c23f639723b4> in <module>
#       2 listings = db.crypto_history.find()
#       3
# ----> 4 df = pd.DataFrame(list(db.crypto_history.find()))
#       5
#       6 df
#
# ~/opt/anaconda3/envs/MongoEnv/lib/python3.8/site-packages/pymongo/cursor.py in next(self)
#    1205         if self.__empty:
#    1206             raise StopIteration
# -> 1207         if len(self.__data) or self._refresh():
#    1208             if self.__manipulate:
#    1209                 _db = self.__collection.database
#
# ~/opt/anaconda3/envs/MongoEnv/lib/python3.8/site-packages/pymongo/cursor.py in _refresh(self)
#    1098
#    1099         if not self.__session:
# -> 1100             self.__session = self.__collection.database.client._ensure_session()
#    1101
#    1102         if self.__id is None:  # Query
#
# ...

# %%
# Display VIX items in MongoDB collection as a pandas dataframe
listings = db.VIX.find()

df1 = pd.DataFrame(list(db.VIX.find()))

df1
# Out:
#                            _id                   Name Symbol                Date       High        Low       Open      Close    Volume  Marketcap  Adj Close
# 0     6059656cf3292431e0249b22  CBOE Volatility Index    VIX 2013-04-30 05:00:00 14.2800000 13.5100000 13.7100000 13.5200000 0.0000000  0.0000000 13.5200000
# 1     6059656cf3292431e0249b23  CBOE Volatility Index    VIX 2013-05-01 05:00:00 14.6700000 13.8700000 13.8800000 14.4900000 0.0000000  0.0000000 14.4900000
# 2     6059656cf3292431e0249b24  CBOE Volatility Index    VIX 2013-05-02 05:00:00 14.4800000 13.5800000 14.4800000 13.5900000 0.0000000  0.0000000 13.5900000
# 3     6059656cf3292431e0249b25  CBOE Volatility Index    VIX 2013-05-03 05:00:00 13.1500000 12.7700000 12.9200000 12.8500000 0.0000000  0.0000000 12.8500000
# 4     6059656cf3292431e0249b26  CBOE Volatility Index    VIX 2013-05-06 05:00:00 13.1900000 12.6600000 13.0600000 12.6600000 0.0000000  0.0000000 12.6600000
# ...

# %%
# Display Gold items in MongoDB collection as a pandas dataframe
listings = db.Gold.find()

df2 = pd.DataFrame(list(db.Gold.find()))

df2
# Out:
#                            _id                        Name  Symbol                Date         High          Low         Open        Close        Volume  Marketcap    Adj Close
# 0     60596802f3292431e024a2e5  Gold-Price-Linked Exchange  1328.T 2013-04-30 05:00:00 4215.0000000 4140.0000000 4160.0000000 4150.0000000 13420.0000000  0.0000000 4150.0000000
# 1     60596802f3292431e024a2e6  Gold-Price-Linked Exchange  1328.T 2013-05-01 05:00:00 4160.0000000 4115.0000000 4140.0000000 4130.0000000 11770.0000000  0.0000000 4130.0000000
# 2     60596802f3292431e024a2e7  Gold-Price-Linked Exchange  1328.T 2013-05-02 05:00:00 4105.0000000 4060.0000000 4105.0000000 4070.0000000 21650.0000000  0.0000000 4070.0000000
# 3     60596802f3292431e024a2e8  Gold-Price-Linked Exchange  1328.T 2013-05-07 05:00:00 4190.0000000 4140.0000000 4185.0000000 4140.0000000 48080.0000000  0.0000000 4140.0000000
# ...

# %%
# Display Dollar items in MongoDB collection as a pandas dataframe
listings = db.Dollar.find()

df3 = pd.DataFrame(list(db.Dollar.find()))

df3
# Out:
#                            _id       Name Symbol                Date       High        Low       Open      Close    Volume  Marketcap  Adj Close
# 0     60596c27f3292431e024aa82  US Dollar     DX 2016-05-02 05:00:00 93.0700000 92.5400010 93.0199970 92.6299970 0.0000000  0.0000000 92.6299970
# 1     60596c27f3292431e024aa83  US Dollar     DX 2016-05-03 05:00:00 92.9899980 91.9199980 92.5999980 92.9400020 0.0000000  0.0000000 92.9400020
# 2     60596c27f3292431e024aa84  US Dollar     DX 2016-05-04 05:00:00 93.3600010 92.8499980 92.9800030 93.1800000 0.0000000  0.0000000 93.1800000
# 3     60596c27f3292431e024aa85  US Dollar     DX 2016-05-05 05:00:00 93.8600010 93.1699980 93.2200010 93.7799990 0.0000000  0.0000000 93.7799990
# 4     60596c27f3292431e024aa86  US Dollar     DX 2016-05-06 05:00:00 93.9599990 93.2799990 93.7399980 93.8899990 0.0000000  0.0000000 93.8899990
# ...

# %%
# Display SnP items in MongoDB collection as a pandas dataframe
listings = db.SnP.find()

df4 = pd.DataFrame(list(db.SnP.find()))

df4
# Out:
#                            _id             Name Symbol                Date         High          Low         Open        Close          Volume  Marketcap    Adj Close
# 0     60596de6f3292431e024af44   E-Mini S&P 500     ES 2013-04-30 05:00:00 1594.2500000 1581.2500000 1588.5000000 1592.2500000 1555013.0000000  0.0000000 1592.2500000
# 1     60596de6f3292431e024af45   E-Mini S&P 501     ES 2013-05-01 05:00:00 1595.5000000 1576.0000000 1593.7500000 1577.2500000 1467806.0000000  0.0000000 1577.2500000
# 2     60596de6f3292431e024af46   E-Mini S&P 502     ES 2013-05-02 05:00:00 1594.2500000 1578.7500000 1579.2500000 1592.2500000 1652820.0000000  0.0000000 1592.2500000
# 3     60596de6f3292431e024af47   E-Mini S&P 503     ES 2013-05-03 05:00:00 1614.2500000 1589.5000000 1592.2500000 1608.5000000 1936845.0000000  0.0000000 1608.5000000
# ...
